# %%
name="Alice"
age="21"
city="Tirupati"

# %%
print(name,age,city)
# Out:
# Alice 21 Tirupati

# %%
type(age)
# Out:
# str

# %%
y=int(age)
type(y)
# Out:
# int

# %%
a=10
b=20
# Out:
# 30

# %%
a+b,a-b,a*b,a/b,a//b,a**b,a%b
# Out:
# (30, -10, 200, 0.5, 0, 100000000000000000000, 10)

# %%
a>b,a<b,a==b
# Out:
# (False, True, False)

# %%
name="Alice"
age=21
fav_no=9
print(name,age,fav_no)
# Out:
# Alice 21 9
