# %%
age=30
if age>18:
    print("Eligible")
# Out:
# Eligible

# %%
age=10
if age>18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Not Eligible

# %%
age=30
re="Eligible" if age>18 else "Not Eligible"
print(re)
# Out:
# Eligible

# %%
age=30
if age<=10:
    print("child")
elif age<=20:
    print("Teenager")
elif age<=60:
    print("Adult")
else:
    print("")
# Out:
# Adult

# %%
num=30
match num:
    case 10:
        print("Even")
    case 20:
        print("Odd")
    case 30:
        print("Zero")
# Out:
# Zero

# %%
num=91
if num>50:
    print("Greater")
if num>90 and num<100:
    print("True")
# Out:
# Greater
# True

# %%
a = True
b = False

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
a = 10
b = a
b = 20

print(a)
print(b)
# Out:
# 10
# 20

# %%
a = [1,2,3]
b = a

b.append(4)

print(a)
# Out:
# [1, 2, 3, 4]

# %%
a = [1,2,3]
b = a.copy()
b.append(4)
print(a,b)
# Out:
# [1, 2, 3] [1, 2, 3, 4]

# %%
def square(num):
    return num**2
square(5)
# Out:
# 25

# %%
x = 10
def show():
    x = 5
    print(x)
show()
print(x)
# Out:
# 5
# 10

# %%
def evenorodd(n):
    if n%2==0:
        return "Even"
    else:
        return "Odd"
evenorodd(10)
# Out:
# 'Even'

# %%
a=input()
b=input()
print(a and b)
print (a or b)
print(not a)
# Out:
# False
# True
# False

# %%
def change(x):
    x = x + 5
num = 10
change(num)
print(num)
# Out:
# 10

# %%
a=int(input())
b=int(input())
if a>b:
    print("a is greater")
elif a<b:
    print("b is greater")
else:
    print("a is equal to b")
# Out:
# b is greater
