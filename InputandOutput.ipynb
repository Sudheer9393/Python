# %%
name=input("Enter your name:")
print(name)
# Out:
# Sudheer

# %%
print("Your name is",name)
# Out:
# Your name is Sudheer

# %%
age=21
city="Tirupati"
print(name,age,city)
# Out:
# Sudheer 21 Tirupati

# %%
x,y=map(int,input("Enter numbers:").split())
print(x)
print(y)
type(x)
# Out:
# 10
# 20
# int

# %%
name=input("Enter your name:")
print("Hello",name)
# Out:
# Hello Alice

# %%
a=int(input())
b=int(input())
print(a+b,a*b)
# Out:
# 30 200

# %%
a=b=c=3
print(type(10))
print(type(10.5))
print(type("10"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=10
b=5
c=2
print((a+b)*c)
(10 + 5) * 2
# Out:
# 30
# 30
